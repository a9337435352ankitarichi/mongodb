# %% [markdown]
# # Generating summary statistics for the entire dataset

# %%
import pandas as pd

accidents_data_file='accidents.csv'

accidents=pd.read_csv(accidents_data_file,
                     sep=',',
                     index_col=False,
                     header=0,
                     parse_dates=['Date'],
                     dayfirst=True,
                     tupleize_cols=False,
                     error_bad_lines=True,
                     warn_bad_lines=True,
                     skip_blank_lines=True)

# %% [markdown]
# Generating summary statistics of the entire accidents dataset

# %%
accidents.describe()
# Out:
#        Location_Easting_OSGR   Location_Northing_OSGR    Longitude  \
# count             5709.000000             5709.000000  5709.000000
# mean            460384.466281           452237.166229    -1.080970
# std               2784.455309             2779.359622     0.042521
# min             451058.000000           443248.000000    -1.223049
# 25%             458790.000000           451090.000000    -1.105473
# 50%             460267.000000           451852.000000    -1.082811
# 75%             461750.000000           453577.000000    -1.060533
# max             470395.000000           462450.000000    -0.928845
#
#           Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# count  5709.000000        5709.0        5709.000000         5709.000000
# mean     53.962675          12.0           2.846033            1.855491
# std       0.024932           0.0           0.388532            0.658056
# min      53.881412          12.0           1.000000            1.000000
# ...

# %% [markdown]
# To make the summary statistics more readable we transpose the describe results

# %%
accidents.describe().transpose()
# Out:
#                                               count           mean  \
# Location_Easting_OSGR                        5709.0  460384.466281
# Location_Northing_OSGR                       5709.0  452237.166229
# Longitude                                    5709.0      -1.080970
# Latitude                                     5709.0      53.962675
# Police_Force                                 5709.0      12.000000
# Accident_Severity                            5709.0       2.846033
# Number_of_Vehicles                           5709.0       1.855491
# Number_of_Casualties                         5709.0       1.266947
# Day_of_Week                                  5709.0       4.152391
# Local_Authority_(District)                   5709.0     189.000000
# 1st_Road_Class                               5709.0       4.484148
# 1st_Road_Number                              5709.0     852.632860
# Road_Type                                    5709.0       5.310562
# ...

# %% [markdown]
# # Generating summary statistics for object type columns

# %%
import pandas as pd

accidents_data_file='accidents.csv'
accidents=pd.read_csv(accidents_data_file,
                     sep=',',
                     header=0,
                     index_col=0,
                     parse_dates=['Date'],
                     dayfirst=True,
                     tupleize_cols=False,
                     error_bad_lines=True,
                     warn_bad_lines=True,
                     skip_blank_lines=True)

# %% [markdown]
# Printing the summary statistics of object type columns

# %%
accidents.describe(include=['object'])
# Out:
#                     Time Local_Authority_(Highway) LSOA_of_Accident_Location
# count               5709                      5709                      5700
# unique              1037                         1                       125
# top     17:30:00.0000000                 E06000014                 E01013366
# freq                  73                      5709                       263

# %% [markdown]
# # Getting the mode of the entire dataset

# %%
import pandas as pd

accidents_data_file='accidents.csv'

accidents=pd.read_csv(accidents_data_file,
                     sep=',',
                     header=0,
                     index_col=False,
                     parse_dates=['Date'],
                     dayfirst=True,
                     tupleize_cols=False,
                     error_bad_lines=True,
                     warn_bad_lines=True,
                     skip_blank_lines=True)

accidents.mode().transpose()

#mode is the value that occurs most often in the column of the dataset
# Out:
#                                                             0     \
# Accident_Index                                     2005120010376
# Location_Easting_OSGR                                     460870
# Location_Northing_OSGR                                    451630
# Longitude                                              -0.990335
# Latitude                                                 54.0129
# Police_Force                                                  12
# Accident_Severity                                              3
# Number_of_Vehicles                                             2
# Number_of_Casualties                                           1
# Date                                         2006-11-22 00:00:00
# Day_of_Week                                                    6
# Time                                            17:30:00.0000000
# Local_Authority_(District)                                   189
# ...

# %% [markdown]
# # Generating summary statistics for a single column

# %%
import pandas as pd

accidents_data_file='accidents.csv'

accidents=pd.read_csv(accidents_data_file,
                     sep=',',
                     header=0,
                     index_col=False,
                     tupleize_cols=False,
                     parse_dates=['Date'],
                     dayfirst=True,
                      error_bad_lines=True,
                      warn_bad_lines=True,
                      skip_blank_lines=True
                     )

# %%
#summary statistics of Weather_conditions column
accidents['Weather_Conditions'].describe()
# Out:
# count    5709.000000
# mean        1.463829
# std         1.481714
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         9.000000
# Name: Weather_Conditions, dtype: float64

# %% [markdown]
# # Getting a count of unique values for a single column

# %%
import pandas as pd

accidents_data_file='accidents.csv'

accidents=pd.read_csv(accidents_data_file,
                     sep=',',
                     header=0,
                     index_col=False,
                     tupleize_cols=False,
                     parse_dates=['Date'],
                     dayfirst=True,
                     error_bad_lines=True,
                     warn_bad_lines=True,
                     skip_blank_lines=True)

# %%
#to see unique value counts for
pd.value_counts(accidents['Date'])
# Out:
# 2013-11-16    7
# 2014-06-27    7
# 2006-11-22    7
# 2012-06-22    7
# 2005-02-21    6
# 2013-08-15    6
# 2013-08-09    6
# 2007-07-20    6
# 2013-10-09    6
# 2014-09-26    6
# 2008-10-14    6
# 2014-09-30    6
# 2006-10-06    6
# 2009-10-10    6
# 2008-04-24    6
# 2005-11-09    6
# 2010-10-07    6
# 2008-01-14    6
# 2016-02-13    6
# 2005-10-19    5
# 2013-06-09    5
# 2008-11-07    5
# 2012-12-05    5
# 2006-07-09    5
# 2006-07-14    5
# 2005-08-02    5
# 2010-11-15    5
# 2008-10-24    5
# 2013-11-20    5
# 2009-12-18    5
#              ..
# 2016-01-22    1
# 2010-01-17    1
# 2015-06-13    1
# 2016-08-03    1
# 2014-08-15    1
# 2012-05-03    1
# 2007-10-22    1
# 2012-12-12    1
# 2006-08-18    1
# 2005-11-18    1
# 2007-10-10    1
# 2013-11-15    1
# 2008-02-02    1
# 2006-10-22    1
# 2006-03-14    1
# 2007-05-27    1
# 2006-12-29    1
# 2005-03-26    1
# 2016-08-25    1
# 2010-06-02    1
# 2010-12-08    1
# 2008-08-26    1
# 2016-03-19    1
# 2014-05-12    1
# ...

# %% [markdown]
# # Getting the minimum and maximum values of a single column

# %%
# Get the count of each unique value in the Date column.
print("Min Value: {}".format(accidents['Number_of_Vehicles'].min()))
print("Max Value: {}".format(accidents['Number_of_Vehicles'].max()))
# Out:
# Min Value: 1
# Max Value: 9

# %% [markdown]
# # Generating quantiles for a single column

# %%
#creating quantiles for the column Number_of_Vehicles
accidents['Number_of_Vehicles'].quantile([.05, .1, .25, .5, .75, .9, .99])
# Out:
# 0.05    1.0
# 0.10    1.0
# 0.25    1.0
# 0.50    2.0
# 0.75    2.0
# 0.90    2.0
# 0.99    4.0
# Name: Number_of_Vehicles, dtype: float64

# %% [markdown]
# # Getting the mean,median,mode and range of a single column

# %%
print("Mean: {}".format(accidents['Number_of_Vehicles'].mean()))
# Out:
# Mean: 1.8554913294797688

# %%
print("Median: {}".format(accidents['Number_of_Vehicles'].median()))
# Out:
# Median: 2.0

# %%
print("Mode: {}".format(accidents['Number_of_Vehicles'].mode()))
# Out:
# Mode: 0    2
# dtype: int64

# %%
print("Range: {}".format(range(accidents['Number_of_Vehicles'].min(),accidents['Number_of_Vehicles'].max())))
# Out:
# Range: range(1, 9)
